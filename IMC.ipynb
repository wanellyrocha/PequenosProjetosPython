# %% [markdown]
# # **Índice de Massa Corporal**

# %% [markdown]
# ![class_IMC.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Criado no século 19 pelo matemático Lambert Quételet, o Índice de Massa Corporal, conhecido pela sigla IMC, é um cálculo simples que permite medir se alguém está ou não com o peso ideal. Ele aponta se o peso está adequado ou se está abaixo ou acima do peso.
#
# Para fazer o cálculo, basta dividir o peso pela altura ao quadrado.

# %% [markdown]
# ![tab_class_IMC.png](data:image/png;base64,...)

# %% [markdown]
# [IMC - Secretaria de Saúde](https://www.saude.rj.gov.br/obesidade/noticias/2019/03/imc-voce-sabe-o-que-o-indice-de-massa-corporal-diz-sobre-sua-saude)

# %%
altura = float(input('Digite sua altura em metros: '))
peso = float(input('Digite seu peso em KG: '))

imc = peso / altura**2
print('Seu IMC é {:.2f}'.format(imc))

if imc < 16:
	print('Sua classificação IMC: Magreza grave')
elif imc < 17:
	print('Sua classificação IMC: Magreza moderada')
elif imc < 18.5:
	print('Sua classificação IMC: Magreza leve')
elif imc < 25:
	print('Sua classificação IMC: Saudável')
elif imc < 30:
	print('Sua classificação IMC: Sobrepeso')
elif imc < 35:
	print('Sua classificação IMC: Obesidade Grau I')
elif imc < 40:
	print('Sua classificação IMC: Obesidade Grau II (severa)')
else:
	print('Sua classificação IMC: Obesidade Grau III (mórbida)')
# Out:
# Digite sua altura em metros: 1.67
# Digite seu peso em KG: 72
# Seu IMC é 25.82
# Sua classificação IMC: Sobrepeso
